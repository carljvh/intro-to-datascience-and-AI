# %% [markdown]
# DAT405 Assignment 3
#
# Theodor Jendle - 9901134339 -
#
# Carl Hjalmarsson - 9305198930 -

# %%
import nbdime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

prot_angles = pd.read_csv("assignment3-data.csv", index_col = False)

prot_angles
# Out:
#       residue name  position chain         phi         psi
# 0              LYS        10     A -149.312855  142.657714
# 1              PRO        11     A  -44.283210  136.002076
# 2              LYS        12     A -119.972621 -168.705263
# 3              LEU        13     A -135.317212  137.143523
# 4              LEU        14     A -104.851467   95.928520
# ...            ...       ...   ...         ...         ...
# 29364          GLY       374     B -147.749557  155.223562
# 29365          GLN       375     B -117.428541  133.019506
# 29366          ILE       376     B -113.586448  112.091970
# 29367          ASN       377     B -100.668779  -12.102821
# 29368          LYS       378     B -169.951240   94.233680
#
# [29369 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statistics as st
from sklearn import datasets
import os
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

data_folder = "data"
protein_file = os.path.join(data_folder, "assignment3-data.csv")
protein_data = pd.read_csv(protein_file, index_col = False)

phi_data = protein_data["phi"]
psi_data = protein_data["psi"]

#for ix in range(len(protein_data)):
#    phi_data[ix] = protein_data.phi[ix]
#    psi_data[ix] = protein_data.phi[ix]

N = len(phi_data)
colors = np.random.rand(N)
plt.scatter(phi_data, psi_data, c = colors)
plt.xlabel("phi")
plt.ylabel("psi")
plt.title("Figure 1: Angels of rotation for a protein chain")
plt.show()

heatmap, xedges, yedges = np.histogram2d(phi_data, psi_data, bins=50)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.clf()
plt.imshow(heatmap.T, extent=extent, origin='lower')
plt.show()
